# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load dataset

# %%
import pandas as pd
import numpy as np

featured_movies_df = pd.read_pickle('data/raw_data/featured_movies_dataframe.pkl')
featured_movies_df.columns
# Out:
# Index(['BrdCstClassKey', 'adult', 'day', 'doy', 'duration', 'genres', 'hour',
#        'is_weekend', 'month', 'original_language', 'pdm', 'popularity',
#        'public_holiday', 'release_date', 'revenue', 'rt_m', 'season',
#        'start_time', 'title', 'tmdb_id', 'vote_average', 'weekday', 'year'],
#       dtype='object')

# %%
# Adult = False as default
featured_movies_df['adult'] = np.where(
    featured_movies_df['adult'].isna(),         # condition per-row
    False,                                      # value if True
    featured_movies_df['adult']                 # value if False
)

# Missing original_language put as 'unknown'
featured_movies_df['original_language'] = np.where(
    featured_movies_df['original_language'].isna(),         # condition per-row
    'unknown',                                              # value if True
    featured_movies_df['original_language']                 # value if False
)

featured_movies_df['genres'] = featured_movies_df['genres'].apply(
    lambda x: x if isinstance(x, list) else []
)

# Missing release_date put as '1900-01-01'
featured_movies_df['release_date'] = np.where(
    featured_movies_df['release_date'].isna(),         # condition per-row
    '1900-01-01',                                      # value if True
    featured_movies_df['release_date']                 # value if False
)

# Add a missing_release_date flag
featured_movies_df.loc[:, 'missing_release_date'] = np.where(
    featured_movies_df['release_date'].isna(),  # condition per-row
    False,                                      # value if True
    True                                        # value if False
)
featured_movies_df.loc[:, 'missing_release_date'] = featured_movies_df.loc[:, 'missing_release_date'].apply(lambda s: False if s == '' else True)
featured_movies_df.loc[:, 'release_date'] = featured_movies_df.loc[:, 'release_date'].apply(lambda s: '1900-01-01' if s == '' else s)

# Missing Revenue put as 0 similarly to TMDB API
featured_movies_df['revenue'] = np.where(
    featured_movies_df['revenue'].isna(),         # condition per-row
    0,                                            # value if True
    featured_movies_df['revenue']                 # value if False
)

# missing tmdb id flag
featured_movies_df.loc[:, 'missing_tmdb'] = np.where(
    featured_movies_df['tmdb_id'].isna(),  # condition per-row
    True,                                  # value if True
    False                                  # value if False
)

# Add vote average as zero
featured_movies_df.loc[:, 'vote_average'] = featured_movies_df['vote_average'].fillna(0)

#  Add popularity zero 
featured_movies_df.loc[:, 'popularity'] = featured_movies_df['popularity'].fillna(0)

# Separate Movies and TV Shows
featured_movies_df.loc[:, 'is_movie'] = True

# %%
# Place title as first column
featured_movies_df = featured_movies_df[['title']+featured_movies_df.drop(columns=['title']).columns.tolist()]

# %%
drop = ['day', 'doy', 'hour',
       'is_weekend', 'month', 'pdm', 
       'public_holiday', 'rt_m',
       'start_time', 'weekday', 'year', 'season']
featured_movies_df = featured_movies_df.drop(columns=drop)

# %%
featured_movies_df
# Out:
#                                       title BrdCstClassKey  adult    duration  \
# 22                                Cher Noël             72  False   86.116667
# 24           James Bond: Jamais plus jamais             71  False  126.333333
# 32                   Super-héros malgré lui             71  False   77.350000
# 33     Qu'est-ce qu'on a fait au Bon Dieu ?             71  False   93.716667
# 34                    Séduis-moi si tu peux             71  False  112.800000
# ...                                     ...            ...    ...         ...
# 17763                Rencard avec le diable             72  False   85.283333
# 17779                        What We Become             71  False   52.250000
# 17812                             Adorables             71  False   89.983333
# 17813                     Illusions perdues             71  False  146.483333
# 17814                           Locked Down             71  False   58.516667
#
#                                                   genres original_language  \
# 22     [{'id': 10770, 'name': 'Téléfilm'}, {'id': 107...                en
# 24     [{'id': 12, 'name': 'Aventure'}, {'id': 28, 'n...                en
# 32     [{'id': 35, 'name': 'Comédie'}, {'id': 28, 'na...                fr
# 33                       [{'id': 35, 'name': 'Comédie'}]                fr
# 34     [{'id': 35, 'name': 'Comédie'}, {'id': 10749, ...                en
# ...                                                  ...               ...
# 17763  [{'id': 10770, 'name': 'Téléfilm'}, {'id': 18,...                en
# 17779  [{'id': 27, 'name': 'Horreur'}, {'id': 53, 'na...                da
# 17812                    [{'id': 35, 'name': 'Comédie'}]                fr
# 17813  [{'id': 35, 'name': 'Comédie'}, {'id': 10749, ...                en
# 17814  [{'id': 35, 'name': 'Comédie'}, {'id': 80, 'na...                en
#
#        popularity release_date      revenue    tmdb_id  vote_average  \
# 22         0.2812   2020-11-27          0.0   744941.0         6.657
# 24        15.4075   1983-10-07  160000000.0    36670.0         6.049
# 32         1.7759   2022-02-02    7375119.0   746333.0         6.352
# 33         2.7478   2014-04-16  176404493.0   262391.0         6.663
# 34         3.1147   2019-05-02          0.0   459992.0         6.725
# ...           ...          ...          ...        ...           ...
# 17763      0.1858   2022-09-14          0.0  1025208.0         6.500
# 17779      0.5022   2015-09-29          0.0   356326.0         5.552
# 17812      0.4237   2020-07-22          0.0   701437.0         5.880
# 17813      0.5496   1941-04-20          0.0    43799.0         6.560
# 17814      1.6434   2021-02-25          0.0   741228.0         5.200
#
#        missing_release_date  missing_tmdb  is_movie
# 22                     True         False      True
# 24                     True         False      True
# 32                     True         False      True
# 33                     True         False      True
# 34                     True         False      True
# ...                     ...           ...       ...
# 17763                  True         False      True
# 17779                  True         False      True
# 17812                  True         False      True
# 17813                  True         False      True
# 17814                  True         False      True
#
# [973 rows x 14 columns]

# %%
catalog_df = featured_movies_df.drop_duplicates(subset=['title'], keep='first')
catalog_df.reset_index(drop=True, inplace=True)

# %%
catalog_df
# Out:
#                                     title BrdCstClassKey  adult    duration  \
# 0                               Cher Noël             72  False   86.116667
# 1          James Bond: Jamais plus jamais             71  False  126.333333
# 2                  Super-héros malgré lui             71  False   77.350000
# 3    Qu'est-ce qu'on a fait au Bon Dieu ?             71  False   93.716667
# 4                   Séduis-moi si tu peux             71  False  112.800000
# ..                                    ...            ...    ...         ...
# 885                  La fillette sans nom             72  False   89.983333
# 886                Rencard avec le diable             72  False   85.283333
# 887                        What We Become             71  False   52.250000
# 888                             Adorables             71  False   89.983333
# 889                     Illusions perdues             71  False  146.483333
#
#                                                 genres original_language  \
# 0    [{'id': 10770, 'name': 'Téléfilm'}, {'id': 107...                en
# 1    [{'id': 12, 'name': 'Aventure'}, {'id': 28, 'n...                en
# 2    [{'id': 35, 'name': 'Comédie'}, {'id': 28, 'na...                fr
# 3                      [{'id': 35, 'name': 'Comédie'}]                fr
# 4    [{'id': 35, 'name': 'Comédie'}, {'id': 10749, ...                en
# ..                                                 ...               ...
# 885                                                 []           unknown
# 886  [{'id': 10770, 'name': 'Téléfilm'}, {'id': 18,...                en
# 887  [{'id': 27, 'name': 'Horreur'}, {'id': 53, 'na...                da
# 888                    [{'id': 35, 'name': 'Comédie'}]                fr
# 889  [{'id': 35, 'name': 'Comédie'}, {'id': 10749, ...                en
#
#      popularity release_date      revenue    tmdb_id  vote_average  \
# 0        0.2812   2020-11-27          0.0   744941.0         6.657
# 1       15.4075   1983-10-07  160000000.0    36670.0         6.049
# 2        1.7759   2022-02-02    7375119.0   746333.0         6.352
# 3        2.7478   2014-04-16  176404493.0   262391.0         6.663
# 4        3.1147   2019-05-02          0.0   459992.0         6.725
# ..          ...          ...          ...        ...           ...
# 885      0.0000   1900-01-01          0.0        NaN         0.000
# 886      0.1858   2022-09-14          0.0  1025208.0         6.500
# 887      0.5022   2015-09-29          0.0   356326.0         5.552
# 888      0.4237   2020-07-22          0.0   701437.0         5.880
# 889      0.5496   1941-04-20          0.0    43799.0         6.560
#
#      missing_release_date  missing_tmdb  is_movie
# 0                    True         False      True
# 1                    True         False      True
# 2                    True         False      True
# 3                    True         False      True
# 4                    True         False      True
# ..                    ...           ...       ...
# 885                  True          True      True
# 886                  True         False      True
# 887                  True         False      True
# 888                  True         False      True
# 889                  True         False      True
#
# [890 rows x 14 columns]

# %%
catalog_df.to_pickle("data/catalog_df.pkl")
